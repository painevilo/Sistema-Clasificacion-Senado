# %%
# importa las librerías a nuestro entorno de trabajo
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
    name=fn
df1 = pd.read_csv(name, sep='\s+',header=None)
# Out:
#      <input type="file" id="files-afcfe355-cb23-4b71-aca3-9b67d9d8afdb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-afcfe355-cb23-4b71-aca3-9b67d9d8afdb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving housing.data to housing (4).data

# %%
df1.head()

# %%
df1.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']

# %%
df1
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df1.dtypes

# %%
df1.describe()

# %%
df1.mode()

# %%
df1.median()

# %%
df1.var()

# %%
df1.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,15))
p=sns.heatmap(df1.corr(), annot=True,cmap='RdYlGn',square=True)

# %%
df1_sc_h = df1
df1_sc_h['MEDV'] = df1_sc_h['MEDV']*1000
df1_sc_h
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT     MEDV
# 0       15.3  396.90   4.98  24000.0
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data = scaler.fit_transform(df1_sc_h)
df1_sc_h = pd.DataFrame(scaled_data)
df1_sc_h.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
df1_sc_h
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,15))
p=sns.heatmap(df1_sc_h.corr(), annot=True,cmap='RdYlGn',square=True)

# %%
import seaborn as sb 
  

sb.regplot(x = "CRIM", 
            y = "MEDV",  
            ci = None, 
            data = df1_sc_h)

# %%
df2=df1_sc_h
df2.shape
# Out:
# (506, 14)

# %%
df2.describe()

# %%
#df3=df2
df3 = df2[ df2.CRIM <= 0.4 ]
df3.shape

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,15))
p=sns.heatmap(df3.corr(), annot=True,cmap='RdYlGn',square=True)

# %%
# Generamos las variables Independientes (PRICES) y las independientes (FEATURES)
prices = df2['MEDV']
features = df2.drop('MEDV', axis = 1)
#
#Para probar con las de mayor correlación con PRICES : RM,LSTAT,PTRATIO
#
#features = df2.drop(['CRIM','ZN','INDUS','CHAS','NOX','AGE','DIS','RAD','TAX','B','MEDV'], axis=1)
#
#Para probar sólo con RM
#
#features = df2.drop(['CRIM','ZN','INDUS','CHAS','NOX','AGE','DIS','RAD','TAX','B','MEDV','PTRATIO','LSTAT'], axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, prices, test_size=0.2, random_state =1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Tipo de modelo
modelo_x = LinearRegression()
# Entrenamiento del modelo
modelo_x.fit(X_train, y_train)
# Validación del modelo
y_pred = modelo_x.predict(X_test)
# Evaluación del modelo
print("R2 :%.2f" % r2_score(y_test, y_pred))
print("MSE: %.2f" % mean_squared_error(y_pred, y_test))
print("Score del modelo : %.2f" % modelo_x.score(X_test,y_test))
# Out:
# R2 :0.76
# MSE: 0.01
# Score del modelo : 0.76

# %%
# Guardamos la prediccion original
#
y_pred_original=y_pred

# %%
# Incrementamos CRIM en un 1%
#
features2 = df2.drop('MEDV', axis = 1)
features2['CRIM'] = features2['CRIM']*1.01

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features2, prices, test_size=0.2, random_state =1)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Tipo de modelo
modelo_x = LinearRegression()
# Entrenamiento del modelo
modelo_x.fit(X_train, y_train)
# Validación del modelo
y_pred = modelo_x.predict(X_test)
# Evaluación del modelo
print("R2 :%.2f" % r2_score(y_test, y_pred))
print("MSE: %.2f" % mean_squared_error(y_pred, y_test))
print("Score del modelo : %.2f" % modelo_x.score(X_test,y_test))
# Out:
# R2 :0.76
# MSE: 0.01
# Score del modelo : 0.76

# %%
#Comparamos ambas predicciones
#
print('y_pred_original','y_pred','\n')
print(np.concatenate((y_pred_original.reshape(len(y_pred_original),1), y_pred.reshape(len(y_pred),1)),1)[:10])
# Out:
# y_pred_original y_pred
#
# [[0.61455626 0.61455626]
#  [0.51318878 0.51318878]
#  [0.28953374 0.28953374]
#  [0.36614924 0.36614924]
#  [0.30723197 0.30723197]
#  [0.33066617 0.33066617]
#  [0.60933664 0.60933664]
#  [0.29035506 0.29035506]
#  [0.4316173  0.4316173 ]
#  [0.48910618 0.48910618]]
